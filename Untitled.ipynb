# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('analysis-public-place-assaults-sexual-assaults-and-robberies-2015-csv.csv')
df
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2015   2016               506653                        Riverhead
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
print(df.size)
print(df.shape)
# Out:
# 28280
# (2020, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2020 entries, 0 to 2019
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Index                                  2020 non-null   int64
#  1   Area_unit_2013_code                    2020 non-null   int64
#  2   Area_unit_2013_label                   2020 non-null   object
#  3   Victimisations_calendar_year_2015      2020 non-null   int64
#  4   Population_mid_point_2015              2020 non-null   int64
#  5    Rate_per_10000_population             2020 non-null   object
#  6    Rate_ratio_NZ_average_rate            2020 non-null   object
#  7   Urban_area_2013_code                   2020 non-null   int64
#  8   Urban_area_2013_label                  2020 non-null   object
#  9   Urban_area_type                        2020 non-null   object
# ...

# %%
df.head()
# Out:
#    Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0      1               514102            Auckland Central West
# 1      2               573101  Willis Street-Cambridge Terrace
# 2      3               529700                 Hamilton Central
# 3      4               514103            Auckland Central East
# 4      5               591500                 Cathedral Square
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
# 2                                380                       3170
# 3                                375                      13250
# 4                                305                        570
#
#    Rate_per_10000_population   Rate_ratio_NZ_average_rate   \
# 0                         346                          6.6
# 1                         539                         10.3
# ...

# %%
df.tail()
# Out:
#       Index  Area_unit_2013_code Area_unit_2013_label  \
# 2015   2016               506653            Riverhead
# 2016   2017               610601             Grasmere
# 2017   2018               536513       Bethlehem East
# 2018   2019               574302            Te Kainga
# 2019   2020               527007        Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 2015                                  0                       3510
# 2016                                  0                       3590
# 2017                                  0                       3590
# 2018                                  0                       4020
# 2019                                  0                       5440
#
#       Rate_per_10000_population   Rate_ratio_NZ_average_rate   \
# 2015                        -                            -
# 2016                        -                            -
# ...

# %%
df['Area_unit_2013_label'].value_counts().sort_values(ascending=False)
# Out:
# Area_unit_2013_label
# Auckland Central West    1
# Paparua                  1
# Auckland Central East    1
# Cathedral Square         1
# Auckland Harbourside     1
#                         ..
# Bethlehem East           1
# Te Kainga                1
# Wingatui                 1
# Mangaroa                 1
# Horsham Downs            1
# Name: count, Length: 2020, dtype: int64

# %%
df.sort_values(by="Victimisations_calendar_year_2015",ascending=False).head(10)
# Out:
#    Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0      1               514102            Auckland Central West
# 1      2               573101  Willis Street-Cambridge Terrace
# 2      3               529700                 Hamilton Central
# 3      4               514103            Auckland Central East
# 4      5               591500                 Cathedral Square
# 5      6               514101             Auckland Harbourside
# 6      7               524604                  Manukau Central
# 7      8               562800         Palmerston North Central
# 8      9               540410                           Kuirau
# 9     10               538201                 Tauranga Central
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
# 2                                380                       3170
# ...

# %%
b= df[df['Victimisations_calendar_year_2015']!= 0]
b.sort_values(by='Victimisations_calendar_year_2015',ascending=True).head(10)
# Out:
#       Index  Area_unit_2013_code Area_unit_2013_label  \
# 1612   1613               516302     Meadowbank South
# 1471   1472               545911               Tutira
# 1470   1471               566610            Akatarawa
# 1469   1470               551120                Okato
# 1468   1469               521116             Buckland
# 1467   1468               584940              Haupiri
# 1466   1467               586126        Woodend Beach
# 1465   1466               565400            Pencarrow
# 1464   1465               609700   Edendale Community
# 1463   1464               532601              Raurimu
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 1612                                  1                       5560
# 1471                                  1                        610
# 1470                                  1                        610
# 1469                                  1                        600
# ...

# %%
df[(df['Population_mid_point_2015']>10000) &(df['Victimisations_calendar_year_2015']>100)]
# Out:
#    Index  Area_unit_2013_code   Area_unit_2013_label  \
# 0      1               514102  Auckland Central West
# 3      4               514103  Auckland Central East
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 3                                375                      13250
#
#    Rate_per_10000_population   Rate_ratio_NZ_average_rate   \
# 0                         346                          6.6
# 3                         283                          5.4
#
#    Urban_area_2013_code  Urban_area_2013_label  Urban_area_type  \
# 0                     4  Central Auckland Zone  Main urban area
# 3                     4  Central Auckland Zone  Main urban area
#
#    Territorial_authority_area_2013_code Territorial_authority_area_2013_label  \
# 0                                    76                              Auckland
# ...

# %%
df[df[' Rate_per_10000_population ']==' -   ']
# Out:
#       Index  Area_unit_2013_code     Area_unit_2013_label  \
# 501     502               604300               Caledonian
# 1238   1239               620000  Inland Water-Lake Taupo
# 1239   1240               623801         Inlet-Tasman Bay
# 1240   1241               581834            Rabbit Island
# 1241   1242               536508   Inlet-Tauranga Harbour
# ...     ...                  ...                      ...
# 2015   2016               506653                Riverhead
# 2016   2017               610601                 Grasmere
# 2017   2018               536513           Bethlehem East
# 2018   2019               574302                Te Kainga
# 2019   2020               527007            Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 501                                  13                          0
# 1238                                  2                          0
# ...

# %%
df[' Rate_per_10000_population ']= df[' Rate_per_10000_population '].replace(' -   ',np.nan)

# %%
df[' Rate_per_10000_population '] =  df[' Rate_per_10000_population '].str.replace(',','',regex=False)

# %%
df[' Rate_per_10000_population ']= pd.to_numeric(df[' Rate_per_10000_population '])

# %%
df[' Rate_per_10000_population '].dtype
# Out:
# dtype('float64')

# %%
df[(df[' Rate_per_10000_population ']>500)]
# Out:
#       Index  Area_unit_2013_code               Area_unit_2013_label  \
# 1         2               573101    Willis Street-Cambridge Terrace
# 2         3               529700                   Hamilton Central
# 4         5               591500                   Cathedral Square
# 6         7               524604                    Manukau Central
# 7         8               562800           Palmerston North Central
# 8         9               540410                             Kuirau
# 9        10               538201                   Tauranga Central
# 12       13               582500                          Trafalgar
# 15       16               587821                            Paparua
# 22       23               551800               New Plymouth Central
# 24       25               570800                    Porirua Central
# 31       32               503100                  Whangarei Central
# 37       38               591600                        Hagley Park
# ...

# %%
df.head()
# Out:
#    Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0      1               514102            Auckland Central West
# 1      2               573101  Willis Street-Cambridge Terrace
# 2      3               529700                 Hamilton Central
# 3      4               514103            Auckland Central East
# 4      5               591500                 Cathedral Square
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
# 2                                380                       3170
# 3                                375                      13250
# 4                                305                        570
#
#     Rate_per_10000_population   Rate_ratio_NZ_average_rate   \
# 0                        346.0                          6.6
# 1                        539.0                         10.3
# ...

# %%
df[' Rate_ratio_NZ_average_rate '].value_counts().sort_values(ascending=False)
# Out:
#  Rate_ratio_NZ_average_rate
#  -       417
# 0.2      181
# 0.3      163
# 0.4      129
# 0.5      128
#         ...
# 8.5        1
# 14.3       1
# 5.6        1
# 102.3      1
# 6.6        1
# Name: count, Length: 102, dtype: int64

# %%
df[' Rate_ratio_NZ_average_rate '] = df[' Rate_ratio_NZ_average_rate '].replace(' -   ',np.nan)

# %%
df[' Rate_ratio_NZ_average_rate ']= pd.to_numeric(df[' Rate_ratio_NZ_average_rate '])

# %%
df[df[' Rate_ratio_NZ_average_rate ']>5]
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 1399   1400               617501     Oceanic-Auckland Region East
# 1400   1401               574303                   Ngauranga West
# 1401   1402               522605             Half Moon Bay Marina
# 1402   1403               501613                   Bay of Islands
# 1403   1404               617703                    Tamaki Strait
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
df['victimisations_per_1000'] = (df['Victimisations_calendar_year_2015']*1000)/df['Population_mid_point_2015']

# %%
df.head()
# Out:
#    Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0      1               514102            Auckland Central West
# 1      2               573101  Willis Street-Cambridge Terrace
# 2      3               529700                 Hamilton Central
# 3      4               514103            Auckland Central East
# 4      5               591500                 Cathedral Square
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
# 2                                380                       3170
# 3                                375                      13250
# 4                                305                        570
#
#     Rate_per_10000_population    Rate_ratio_NZ_average_rate   \
# 0                        346.0                           6.6
# 1                        539.0                          10.3
# ...

# %%
df.sort_values(by='victimisations_per_1000',ascending=False).head(10)['Area_unit_2013_label']
# Out:
# 1240                 Rabbit Island
# 1238       Inland Water-Lake Taupo
# 501                     Caledonian
# 1398         Oceanic-Tasman Region
# 1397    Inland Water-Lake Wakatipu
# 1396         Inlet-Manukau Harbour
# 1395            Tidal-Eastern Bays
# 1394          Inlet-Port Whangarei
# 1239              Inlet-Tasman Bay
# 1241        Inlet-Tauranga Harbour
# Name: Area_unit_2013_label, dtype: object

# %%
df.groupby('Region_2013_label')['Victimisations_calendar_year_2015'].sum().sort_values(ascending=False)
# Out:
# Region_2013_label
# Auckland Region             8010
# Canterbury Region           2942
# Wellington Region           2459
# Waikato Region              2330
# Bay of Plenty Region        1751
# Manawatu-Wanganui Region    1270
# Otago Region                1142
# Hawke's Bay Region          1068
# Northland Region             905
# Taranaki Region              493
# Gisborne Region              436
# Southland Region             381
# Nelson Region                357
# Marlborough Region           209
# Tasman Region                161
# West Coast Region            121
# Area Outside Region            0
# Name: Victimisations_calendar_year_2015, dtype: int64

# %%
df.groupby('Region_2013_label')['Victimisations_calendar_year_2015'].mean().sort_values(ascending=False)
# Out:
# Region_2013_label
# Auckland Region             18.329519
# Gisborne Region             18.166667
# Bay of Plenty Region        13.573643
# Hawke's Bay Region          12.714286
# Wellington Region           11.544601
# Nelson Region               11.516129
# Canterbury Region           11.403101
# Waikato Region              11.148325
# Manawatu-Wanganui Region     9.844961
# Northland Region             9.329897
# Otago Region                 8.651515
# Marlborough Region           8.038462
# Taranaki Region              7.469697
# Tasman Region                5.366667
# Southland Region             4.822785
# West Coast Region            2.122807
# Area Outside Region          0.000000
# Name: Victimisations_calendar_year_2015, dtype: float64

# %%
df.groupby('Region_2013_label')['Population_mid_point_2015'].mean().sort_values(ascending=False)
# Out:
# Region_2013_label
# Auckland Region             3592.425629
# Wellington Region           2332.816901
# Canterbury Region           2272.519380
# Bay of Plenty Region        2225.813953
# Waikato Region              2100.478469
# Gisborne Region             1973.750000
# Hawke's Bay Region          1904.880952
# Manawatu-Wanganui Region    1817.519380
# Taranaki Region             1753.939394
# Marlborough Region          1743.846154
# Northland Region            1735.257732
# Tasman Region               1650.000000
# Otago Region                1629.015152
# Nelson Region               1610.967742
# Southland Region            1230.253165
# West Coast Region            573.684211
# Area Outside Region           32.105263
# Name: Population_mid_point_2015, dtype: float64

# %% [markdown]
# Q.11

# %%
df.groupby('Region_2013_label')['Victimisations_calendar_year_2015'].max().sort_values(ascending= False)
# Out:
# Region_2013_label
# Auckland Region             550
# Wellington Region           447
# Waikato Region              380
# Canterbury Region           305
# Manawatu-Wanganui Region    190
# Bay of Plenty Region        168
# Otago Region                154
# Nelson Region               138
# Hawke's Bay Region          130
# Gisborne Region             128
# Taranaki Region             102
# Marlborough Region           91
# Northland Region             87
# Southland Region             73
# Tasman Region                34
# West Coast Region            20
# Area Outside Region           0
# Name: Victimisations_calendar_year_2015, dtype: int64

# %%
df.head(2)
# Out:
#    Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0      1               514102            Auckland Central West
# 1      2               573101  Willis Street-Cambridge Terrace
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
#
#     Rate_per_10000_population    Rate_ratio_NZ_average_rate   \
# 0                        346.0                           6.6
# 1                        539.0                          10.3
#
#    Urban_area_2013_code  Urban_area_2013_label  Urban_area_type  \
# 0                     4  Central Auckland Zone  Main urban area
# 1                    20        Wellington Zone  Main urban area
#
#    Territorial_authority_area_2013_code Territorial_authority_area_2013_label  \
# 0                                    76                              Auckland
# ...

# %%
idx = df.groupby('Region_2013_label')['Victimisations_calendar_year_2015'].idxmax()
df.loc[idx,['Area_unit_2013_label']]
# Out:
#                  Area_unit_2013_label
# 1615           Oceanic-Snares Islands
# 0               Auckland Central West
# 8                              Kuirau
# 4                    Cathedral Square
# 14                   Gisborne Central
# 13                   Hastings Central
# 7            Palmerston North Central
# 26                   Blenheim Central
# 12                          Trafalgar
# 31                  Whangarei Central
# 10             Stuart St-Frederick St
# 43                       Otakaro Park
# 22               New Plymouth Central
# 149                      Motueka West
# 2                    Hamilton Central
# 1     Willis Street-Cambridge Terrace
# 328                   Greymouth South

# %%
df.groupby('Territorial_authority_area_2013_label')[['Population_mid_point_2015','Victimisations_calendar_year_2015']].sum()
# Out:
#                                        Population_mid_point_2015  \
# Territorial_authority_area_2013_label
# Area Outside Territorial Authority                            40
# Ashburton District                                         33160
# Auckland                                                 1569890
# Buller District                                            10350
# Carterton District                                          8790
# ...                                                          ...
# Wellington City                                           203810
# Western Bay of Plenty District                             46770
# Westland District                                           8720
# Whakatane District                                         34610
# Whangarei District                                         85930
#
#                                        Victimisations_calendar_year_2015
# Territorial_authority_area_2013_label
# ...

# %%
df.groupby('Territorial_authority_area_2013_label')['Victimisations_calendar_year_2015'].sum().sort_values(ascending=False).head(10)
# Out:
# Territorial_authority_area_2013_label
# Auckland                 8010
# Christchurch City        2311
# Hamilton City            1136
# Wellington City          1022
# Tauranga City             691
# Dunedin City              673
# Hastings District         587
# Lower Hutt City           585
# Rotorua District          580
# Palmerston North City     471
# Name: Victimisations_calendar_year_2015, dtype: int64

# %%
df.groupby('Urban_area_type')['Victimisations_calendar_year_2015'].mean()
# Out:
# Urban_area_type
# Main urban area         17.078237
# Minor urban area        14.518248
# Rural area               2.107813
# Secondary urban area    13.022901
# Name: Victimisations_calendar_year_2015, dtype: float64

# %%
df.head(2)
# Out:
#    Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0      1               514102            Auckland Central West
# 1      2               573101  Willis Street-Cambridge Terrace
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
#
#     Rate_per_10000_population    Rate_ratio_NZ_average_rate   \
# 0                        346.0                           6.6
# 1                        539.0                          10.3
#
#    Urban_area_2013_code  Urban_area_2013_label  Urban_area_type  \
# 0                     4  Central Auckland Zone  Main urban area
# 1                    20        Wellington Zone  Main urban area
#
#    Territorial_authority_area_2013_code Territorial_authority_area_2013_label  \
# 0                                    76                              Auckland
# ...

# %%
a = df.groupby('Region_2013_label')['Area_unit_2013_label'].count().sort_values(ascending=False)
a[a>50]
# Out:
# Region_2013_label
# Auckland Region             437
# Canterbury Region           258
# Wellington Region           213
# Waikato Region              209
# Otago Region                132
# Bay of Plenty Region        129
# Manawatu-Wanganui Region    129
# Northland Region             97
# Hawke's Bay Region           84
# Southland Region             79
# Taranaki Region              66
# West Coast Region            57
# Name: Area_unit_2013_label, dtype: int64

# %%
df.groupby('Territorial_authority_area_2013_label')['Victimisations_calendar_year_2015'].mean().sort_values(ascending=False)
# Out:
# Territorial_authority_area_2013_label
# Kawerau District                      59.000000
# Hamilton City                         24.695652
# Gisborne District                     18.956522
# Auckland                              18.329519
# Christchurch City                     17.914729
#                                         ...
# Buller District                        1.562500
# Southland District                     1.473684
# Westland District                      1.368421
# Chatham Islands Territory              0.000000
# Area Outside Territorial Authority     0.000000
# Name: Victimisations_calendar_year_2015, Length: 68, dtype: float64

# %%
abx =df.groupby('Region_2013_label')['Victimisations_calendar_year_2015'].sum().sort_values(ascending=False)
abx[abx>5000]
# Out:
# Region_2013_label
# Auckland Region    8010
# Name: Victimisations_calendar_year_2015, dtype: int64

# %%
bs =df.groupby('Urban_area_2013_label')['Area_unit_2013_label'].count().sort_values(ascending=False)
bs[bs>5]
# Out:
# Urban_area_2013_label
# Rural (Incl.some Off Shore Islands)    387
# Rural Centre                           133
# Christchurch                           133
# Southern Auckland Zone                 111
# Central Auckland Zone                  106
# Wellington Zone                         76
# Northern Auckland Zone                  73
# Western Auckland Zone                   68
# Dunedin                                 61
# Hamilton Zone                           60
# Inlet-in TA but not in Urban Area       57
# Lower Hutt Zone                         41
# Tauranga                                39
# Nelson                                  34
# Hastings Zone                           31
# Whangarei                               29
# Rotorua                                 29
# Wanganui                                27
# New Plymouth                            26
# Palmerston North                        26
# Invercargill                            23
# ...

# %%
beat =df.groupby('Region_2013_label')[' Rate_per_10000_population '].idxmax()
beat = beat.dropna().astype(int)
df.loc[beat,['Area_unit_2013_label','Region_2013_label']]
# Out:
#                    Area_unit_2013_label         Region_2013_label
# 261                           Highbrook           Auckland Region
# 974                       Sulphur Point      Bay of Plenty Region
# 4                      Cathedral Square         Canterbury Region
# 14                     Gisborne Central           Gisborne Region
# 892                            Woolwich        Hawke's Bay Region
# 50                        Cooks Gardens  Manawatu-Wanganui Region
# 1244  Marlborough Sounds Coastal Marine        Marlborough Region
# 12                            Trafalgar             Nelson Region
# 31                    Whangarei Central          Northland Region
# 691                         Harbourside              Otago Region
# 43                         Otakaro Park          Southland Region
# 22                 New Plymouth Central           Taranaki Region
# 387                              Takaka             Tasman Region
# ...

# %% [markdown]
# Q.21

# %%
df.head(1)
# Out:
#    Index  Area_unit_2013_code   Area_unit_2013_label  \
# 0      1               514102  Auckland Central West
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
#
#     Rate_per_10000_population    Rate_ratio_NZ_average_rate   \
# 0                        346.0                           6.6
#
#    Urban_area_2013_code  Urban_area_2013_label  Urban_area_type  \
# 0                     4  Central Auckland Zone  Main urban area
#
#    Territorial_authority_area_2013_code Territorial_authority_area_2013_label  \
# 0                                    76                              Auckland
#
#    Region_2013_code Region_2013_label  victimisations_per_1000
# 0                 2   Auckland Region                34.591195

# %%
av = df.groupby('Territorial_authority_area_2013_label')['Victimisations_calendar_year_2015'].max().sort_values(ascending=False)
df.loc[av,['Area_unit_2013_label','Territorial_authority_area_2013_label']]
# Out:
#       Area_unit_2013_label Territorial_authority_area_2013_label
# 550           Orakei South                              Auckland
# 447                Ahuriri                           Napier City
# 380           Harania East                              Auckland
# 305                 Crinan                     Invercargill City
# 190             Palm Beach                         Tauranga City
# ..                     ...                                   ...
# 9         Tauranga Central                         Tauranga City
# 8                   Kuirau                      Rotorua District
# 8                   Kuirau                      Rotorua District
# 0    Auckland Central West                              Auckland
# 0    Auckland Central West                              Auckland
#
# [68 rows x 2 columns]

# %%
ax =df['Victimisations_calendar_year_2015'].sort_values(ascending=False)
df.loc[ax,['Area_unit_2013_label']]
# Out:
#       Area_unit_2013_label
# 550           Orakei South
# 447                Ahuriri
# 380           Harania East
# 375               Viscount
# 305                 Crinan
# ..                     ...
# 0    Auckland Central West
# 0    Auckland Central West
# 0    Auckland Central West
# 0    Auckland Central West
# 0    Auckland Central West
#
# [2020 rows x 1 columns]

# %%
df['region_rank']= df.groupby('Region_2013_label')['Victimisations_calendar_year_2015'].rank(method='dense',ascending=True)

# %%
df[['Region_2013_label','Victimisations_calendar_year_2015','region_rank','Area_unit_2013_label']].sort_values(['Region_2013_label','region_rank'])
# Out:
#         Region_2013_label  Victimisations_calendar_year_2015  region_rank  \
# 1615  Area Outside Region                                  0          1.0
# 1618  Area Outside Region                                  0          1.0
# 1628  Area Outside Region                                  0          1.0
# 1649  Area Outside Region                                  0          1.0
# 1651  Area Outside Region                                  0          1.0
# ...                   ...                                ...          ...
# 579     West Coast Region                                 11          7.0
# 504     West Coast Region                                 13          8.0
# 407     West Coast Region                                 17          9.0
# 337     West Coast Region                                 19         10.0
# 328     West Coast Region                                 20         11.0
#
#            Area_unit_2013_label
# 1615     Oceanic-Snares Islands
# ...

# %%
df.sort_values('Victimisations_calendar_year_2015',ascending=False).groupby('Region_2013_label').head(3)
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# 5         6               514101             Auckland Harbourside
# 7         8               562800         Palmerston North Central
# 8         9               540410                           Kuirau
# 9        10               538201                 Tauranga Central
# 10       11               603100           Stuart St-Frederick St
# 12       13               582500                        Trafalgar
# 13       14               548200                 Hastings Central
# 14       15               544600                 Gisborne Central
# ...

# %%
df.sort_values("Victimisations_calendar_year_2015",ascending=False).groupby('Region_2013_label').head(5)
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 1910   1911               597000                  Chatham Islands
# 1684   1685               614001         Oceanic-Kermadec Islands
# 1686   1687               614002                 Kermadec Islands
# 1689   1690               614503              Three Kings Islands
# 1707   1708               666671                    Snares Island
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
df.sort_values(' Rate_per_10000_population ',ascending=False).head(202)
# Out:
#      Index  Area_unit_2013_code Area_unit_2013_label  \
# 261    262               523112            Highbrook
# 4        5               591500     Cathedral Square
# 69      70               521902           Middlemore
# 31      32               503100    Whangarei Central
# 691    692               602800          Harbourside
# ..     ...                  ...                  ...
# 531    532               554700                Patea
# 182    183               544400     Gisborne Airport
# 306    307               581400    Kaikoura Township
# 106    107               513301             Kingdale
# 63      64               524822        Clendon South
#
#      Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 261                                 23                         40
# 4                                  305                        570
# 69                                  53                        110
# ...

# %%
df.head(1)
# Out:
#    Index  Area_unit_2013_code   Area_unit_2013_label  \
# 0      1               514102  Auckland Central West
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
#
#     Rate_per_10000_population    Rate_ratio_NZ_average_rate   \
# 0                        346.0                           6.6
#
#    Urban_area_2013_code  Urban_area_2013_label  Urban_area_type  \
# 0                     4  Central Auckland Zone  Main urban area
#
#    Territorial_authority_area_2013_code Territorial_authority_area_2013_label  \
# 0                                    76                              Auckland
#
#    Region_2013_code Region_2013_label  victimisations_per_1000  region_rank
# 0                 2   Auckland Region                34.591195         69.0

# %%
df.groupby('Region_2013_label')[' Rate_per_10000_population '].mean().sort_values(ascending=False)
# Out:
# Region_2013_label
# Nelson Region               155.625000
# Northland Region            146.141026
# Auckland Region              91.485640
# Hawke's Bay Region           90.916667
# Gisborne Region              86.350000
# Bay of Plenty Region         86.092593
# Canterbury Region            84.187192
# Wellington Region            83.672414
# Marlborough Region           81.789474
# Manawatu-Wanganui Region     79.926606
# Otago Region                 79.074468
# Waikato Region               76.333333
# Taranaki Region              73.416667
# Southland Region             62.537037
# West Coast Region            55.740741
# Tasman Region                37.894737
# Area Outside Region                NaN
# Name:  Rate_per_10000_population , dtype: float64

# %%
df.groupby('Region_2013_label')['Victimisations_calendar_year_2015'].sum().sort_values(ascending=False)
# Out:
# Region_2013_label
# Auckland Region             8010
# Canterbury Region           2942
# Wellington Region           2459
# Waikato Region              2330
# Bay of Plenty Region        1751
# Manawatu-Wanganui Region    1270
# Otago Region                1142
# Hawke's Bay Region          1068
# Northland Region             905
# Taranaki Region              493
# Gisborne Region              436
# Southland Region             381
# Nelson Region                357
# Marlborough Region           209
# Tasman Region                161
# West Coast Region            121
# Area Outside Region            0
# Name: Victimisations_calendar_year_2015, dtype: int64

# %%
df.groupby('Territorial_authority_area_2013_label')[' Rate_per_10000_population '].mean().sort_values(ascending=False)
# Out:
# Territorial_authority_area_2013_label
# Whangarei District                    208.282051
# Taupo District                        169.190476
# Wanganui District                     165.961538
# Nelson City                           155.625000
# Porirua City                          149.666667
#                                          ...
# Carterton District                     23.000000
# Kapiti Coast District                  22.642857
# Selwyn District                        18.066667
# Area Outside Territorial Authority           NaN
# Chatham Islands Territory                    NaN
# Name:  Rate_per_10000_population , Length: 68, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['rate_score','ratio_score']]=scaler.fit_transform(df[['Victimisations_calendar_year_2015',' Rate_ratio_NZ_average_rate ']])

# %%
df['score']= (df['rate_score']+df['ratio_score'])/2
df
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2015   2016               506653                        Riverhead
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
df.sort_values('score',ascending=False).head(5)
# Out:
#      Index  Area_unit_2013_code             Area_unit_2013_label  \
# 4        5               591500                 Cathedral Square
# 0        1               514102            Auckland Central West
# 261    262               523112                        Highbrook
# 69      70               521902                       Middlemore
# 1        2               573101  Willis Street-Cambridge Terrace
#
#      Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 4                                  305                        570
# 0                                  550                      15900
# 261                                 23                         40
# 69                                  53                        110
# 1                                  447                       8300
#
#       Rate_per_10000_population    Rate_ratio_NZ_average_rate   \
# 4                         5351.0                         102.3
# ...
