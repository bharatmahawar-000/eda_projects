# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as mlp 
import seaborn as sns

# %%
df = pd.read_csv('chinese-tea-dataset.csv')
df
# Out:
#                   id                           name_en name_zh     category  \
# 0     alishan-oolong      Alishan High Mountain Oolong   阿里山乌龙   Oolong Tea
# 1       anji-bai-cha     Anji Bai Cha (Anji White Tea)    安吉白茶    Green Tea
# 2    bai-hao-yinzhen  Bai Hao Yin Zhen (Silver Needle)    白毫银针    White Tea
# 3          bai-mudan           Bai Mudan (White Peony)     白牡丹    White Tea
# 4          biluochun    Biluochun (Green Snail Spring)     碧螺春    Green Tea
# ..               ...                               ...     ...          ...
# 131    zhi-lan-xiang  Zhi Lan Xiang (Orchid Fragrance)     芝兰香   Oolong Tea
# 132      zhu-ye-qing   Zhu Ye Qing (Bamboo Leaf Green)     竹叶青    Green Tea
# 133  lotus-green-tea                   Lotus Green Tea    莲花绿茶  Scented Tea
# 134  magnolia-oolong                   Magnolia Oolong    玉兰乌龙  Scented Tea
# 135     wuzhen-green                      Wuzhen Green    乌镇绿茶    Green Tea
#
# ...

# %%
df.shape
# Out:
# (136, 11)

# %%
df.size
# Out:
# 1496

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 136 non-null    object
#  1   name_en            136 non-null    object
#  2   name_zh            136 non-null    object
#  3   category           136 non-null    object
#  4   region             136 non-null    object
#  5   caffeine_level     136 non-null    object
#  6   body               136 non-null    object
#  7   oxidation_level    136 non-null    float64
#  8   flavor_primary     136 non-null    object
#  9   description_brief  136 non-null    object
#  10  tier               136 non-null    int64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 11.8+ KB

# %%
df.describe()
# Out:
#        oxidation_level        tier
# count       136.000000  136.000000
# mean          0.377500    1.705882
# std           0.362685    0.503582
# min           0.000000    1.000000
# 25%           0.050000    1.000000
# 50%           0.200000    2.000000
# 75%           0.800000    2.000000
# max           1.000000    3.000000

# %%
df.head()
# Out:
#                 id                           name_en name_zh    category  \
# 0   alishan-oolong      Alishan High Mountain Oolong   阿里山乌龙  Oolong Tea
# 1     anji-bai-cha     Anji Bai Cha (Anji White Tea)    安吉白茶   Green Tea
# 2  bai-hao-yinzhen  Bai Hao Yin Zhen (Silver Needle)    白毫银针   White Tea
# 3        bai-mudan           Bai Mudan (White Peony)     白牡丹   White Tea
# 4        biluochun    Biluochun (Green Snail Spring)     碧螺春   Green Tea
#
#               region caffeine_level          body  oxidation_level  \
# 0            Alishan       moderate        medium             0.20
# 1        Anji County            low         light             0.02
# 2             Fuding            low         light             0.08
# 3             Fuding            low  light-medium             0.10
# 4  Dongting Mountain       moderate         light             0.02
#
#           flavor_primary                                  description_brief  \
# ...

# %%
df.tail()
# Out:
#                   id                           name_en name_zh     category  \
# 131    zhi-lan-xiang  Zhi Lan Xiang (Orchid Fragrance)     芝兰香   Oolong Tea
# 132      zhu-ye-qing   Zhu Ye Qing (Bamboo Leaf Green)     竹叶青    Green Tea
# 133  lotus-green-tea                   Lotus Green Tea    莲花绿茶  Scented Tea
# 134  magnolia-oolong                   Magnolia Oolong    玉兰乌龙  Scented Tea
# 135     wuzhen-green                      Wuzhen Green    乌镇绿茶    Green Tea
#
#                region caffeine_level    body  oxidation_level  \
# 131  Phoenix Mountain       moderate  medium             0.45
# 132        Mount Emei       moderate   light             0.02
# 133          Zhejiang            low   light             0.03
# 134            Fujian       moderate  medium             0.30
# 135          Zhejiang            low   light             0.02
#
#               flavor_primary  \
# 131      orchid,floral,sweet
# 132      fresh,vegetal,sweet
# 133       lotus,fresh,floral
# ...

# %%
df[df['tier']==1].count()
# Out:
# id                   43
# name_en              43
# name_zh              43
# category             43
# region               43
# caffeine_level       43
# body                 43
# oxidation_level      43
# flavor_primary       43
# description_brief    43
# tier                 43
# dtype: int64

# %%
df.isna().sum()
# Out:
# id                   0
# name_en              0
# name_zh              0
# category             0
# region               0
# caffeine_level       0
# body                 0
# oxidation_level      0
# flavor_primary       0
# description_brief    0
# tier                 0
# dtype: int64

# %%
df.head()
# Out:
#                 id                           name_en name_zh    category  \
# 0   alishan-oolong      Alishan High Mountain Oolong   阿里山乌龙  Oolong Tea
# 1     anji-bai-cha     Anji Bai Cha (Anji White Tea)    安吉白茶   Green Tea
# 2  bai-hao-yinzhen  Bai Hao Yin Zhen (Silver Needle)    白毫银针   White Tea
# 3        bai-mudan           Bai Mudan (White Peony)     白牡丹   White Tea
# 4        biluochun    Biluochun (Green Snail Spring)     碧螺春   Green Tea
#
#               region caffeine_level          body  oxidation_level  \
# 0            Alishan       moderate        medium             0.20
# 1        Anji County            low         light             0.02
# 2             Fuding            low         light             0.08
# 3             Fuding            low  light-medium             0.10
# 4  Dongting Mountain       moderate         light             0.02
#
#           flavor_primary                                  description_brief  \
# ...

# %%
df['region'].value_counts().sort_values(ascending=False).head()
# Out:
# region
# Fujian            13
# Wuyi Mountains    12
# Yunnan             9
# Menghai            8
# Fuding             8
# Name: count, dtype: int64

# %%
df[df['category']=='Oolong Tea']['oxidation_level'].mean()
# Out:
# np.float64(0.4061764705882353)

# %%
df['body'].value_counts()
# Out:
# body
# medium          46
# light-medium    27
# full            25
# medium-full     20
# light           18
# Name: count, dtype: int64

# %%
df['caffeine_level'].value_counts()
# Out:
# caffeine_level
# moderate    94
# low         25
# high        17
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#                id                        name_en name_zh    category  \
# 0  alishan-oolong   Alishan High Mountain Oolong   阿里山乌龙  Oolong Tea
# 1    anji-bai-cha  Anji Bai Cha (Anji White Tea)    安吉白茶   Green Tea
#
#         region caffeine_level    body  oxidation_level         flavor_primary  \
# 0      Alishan       moderate  medium             0.20    floral,butter,cream
# 1  Anji County            low   light             0.02  umami,chestnut,bamboo
#
#                                    description_brief  tier
# 0  Lightly oxidized oolong from Taiwan's Alishan ...     1
# 1  A unique green tea (not white, despite the nam...     1

# %%
df.loc[df.groupby('category')['oxidation_level'].idxmax().sort_values(ascending=False)]
# Out:
#                        id                              name_en name_zh  \
# 115       weishan-maojian                      Weishan Maojian    沩山毛尖
# 99         rose-black-tea                       Rose Black Tea    玫瑰红茶
# 95        oriental-beauty  Oriental Beauty (Dong Fang Mei Ren)    东方美人
# 54          dinggu-dafang                        Dinggu Dafang    顶谷大方
# 43         aged-white-tea                Aged Fuding White Tea     老白茶
# 27     menghai-shou-puerh                   Menghai Shou Pu'er   勐海熟普洱
# 23                liu-bao                      Liu Bao Hei Cha     六堡茶
# 8    dianhong-gold-needle                 Dianhong Gold Needle    滇红金针
#
#         category   region caffeine_level         body  oxidation_level  \
# 115   Yellow Tea    Hunan       moderate       medium             0.12
# 99   Scented Tea   Yunnan       moderate       medium             0.95
# 95    Oolong Tea   Taiwan       moderate  medium-full             0.70
# ...

# %%
df['flavor_primary'].value_counts()
# Out:
# flavor_primary
# osmanthus,floral,sweet     2
# vegetal,nutty,sweet        2
# chestnut,vegetal,sweet     2
# floral,sweet,delicate      2
# fruit,sweet,smooth         2
#                           ..
# honey,floral,apricot       1
# honey,floral,silky         1
# creamy,floral,long         1
# orchid,creamy,nutty        1
# floral,light,refreshing    1
# Name: count, Length: 127, dtype: int64

# %%
df.head()
# Out:
#                 id                           name_en name_zh    category  \
# 0   alishan-oolong      Alishan High Mountain Oolong   阿里山乌龙  Oolong Tea
# 1     anji-bai-cha     Anji Bai Cha (Anji White Tea)    安吉白茶   Green Tea
# 2  bai-hao-yinzhen  Bai Hao Yin Zhen (Silver Needle)    白毫银针   White Tea
# 3        bai-mudan           Bai Mudan (White Peony)     白牡丹   White Tea
# 4        biluochun    Biluochun (Green Snail Spring)     碧螺春   Green Tea
#
#               region caffeine_level          body  oxidation_level  \
# 0            Alishan       moderate        medium             0.20
# 1        Anji County            low         light             0.02
# 2             Fuding            low         light             0.08
# 3             Fuding            low  light-medium             0.10
# 4  Dongting Mountain       moderate         light             0.02
#
#           flavor_primary                                  description_brief  \
# ...

# %%
df.query("tier > 1")
# Out:
#                   id                           name_en name_zh     category  \
# 43    aged-white-tea             Aged Fuding White Tea     老白茶    White Tea
# 44        anhua-dark                    Anhua Dark Tea    安化黑茶     Dark Tea
# 45       bai-ji-guan     Bai Ji Guan (White Cockscomb)     白鸡冠   Oolong Tea
# 46     bailin-gongfu                     Bailin Gongfu    白琳工夫    Black Tea
# 47           benshan                          Ben Shan      本山   Oolong Tea
# ..               ...                               ...     ...          ...
# 131    zhi-lan-xiang  Zhi Lan Xiang (Orchid Fragrance)     芝兰香   Oolong Tea
# 132      zhu-ye-qing   Zhu Ye Qing (Bamboo Leaf Green)     竹叶青    Green Tea
# 133  lotus-green-tea                   Lotus Green Tea    莲花绿茶  Scented Tea
# 134  magnolia-oolong                   Magnolia Oolong    玉兰乌龙  Scented Tea
# 135     wuzhen-green                      Wuzhen Green    乌镇绿茶    Green Tea
#
# ...

# %%
df[df['category'].isin(['Dark Tea'])]
# Out:
#                   id                         name_en name_zh  category  \
# 23           liu-bao                 Liu Bao Hei Cha     六堡茶  Dark Tea
# 44        anhua-dark                  Anhua Dark Tea    安化黑茶  Dark Tea
# 57          fu-zhuan  Fu Zhuan (Golden Flower Brick)     茯砖茶  Dark Tea
# 60         gong-jian                       Gong Jian      贡尖  Dark Tea
# 70   hubei-qingzhuan                Hubei Qing Zhuan    湖北青砖  Dark Tea
# 80         kangzhuan                      Kang Zhuan      康砖  Dark Tea
# 98     qianliang-cha                   Qianliang Cha     千两茶  Dark Tea
# 105  sichuan-biancha                Sichuan Bian Cha    四川边茶  Dark Tea
# 112        tian-jian                       Tian Jian      天尖  Dark Tea
#
#       region caffeine_level         body  oxidation_level  \
# 23   Guangxi            low  medium-full             0.90
# 44     Hunan            low         full             0.80
# 57     Hunan            low       medium             0.85
# ...

# %%
df.head()
# Out:
#                 id                           name_en name_zh    category  \
# 0   alishan-oolong      Alishan High Mountain Oolong   阿里山乌龙  Oolong Tea
# 1     anji-bai-cha     Anji Bai Cha (Anji White Tea)    安吉白茶   Green Tea
# 2  bai-hao-yinzhen  Bai Hao Yin Zhen (Silver Needle)    白毫银针   White Tea
# 3        bai-mudan           Bai Mudan (White Peony)     白牡丹   White Tea
# 4        biluochun    Biluochun (Green Snail Spring)     碧螺春   Green Tea
#
#               region caffeine_level          body  oxidation_level  \
# 0            Alishan       moderate        medium             0.20
# 1        Anji County            low         light             0.02
# 2             Fuding            low         light             0.08
# 3             Fuding            low  light-medium             0.10
# 4  Dongting Mountain       moderate         light             0.02
#
#           flavor_primary                                  description_brief  \
# ...

# %%
df['caffeine_level'].value_counts()
# Out:
# caffeine_level
# moderate    94
# low         25
# high        17
# Name: count, dtype: int64

# %%
def fp(x) :
    count = 1
    for i in x :
        if i == "," :
            count += 1
    return count
df['fp'] = df['flavor_primary'].apply(fp)

# %%
df
# Out:
#                   id                           name_en name_zh     category  \
# 0     alishan-oolong      Alishan High Mountain Oolong   阿里山乌龙   Oolong Tea
# 1       anji-bai-cha     Anji Bai Cha (Anji White Tea)    安吉白茶    Green Tea
# 2    bai-hao-yinzhen  Bai Hao Yin Zhen (Silver Needle)    白毫银针    White Tea
# 3          bai-mudan           Bai Mudan (White Peony)     白牡丹    White Tea
# 4          biluochun    Biluochun (Green Snail Spring)     碧螺春    Green Tea
# ..               ...                               ...     ...          ...
# 131    zhi-lan-xiang  Zhi Lan Xiang (Orchid Fragrance)     芝兰香   Oolong Tea
# 132      zhu-ye-qing   Zhu Ye Qing (Bamboo Leaf Green)     竹叶青    Green Tea
# 133  lotus-green-tea                   Lotus Green Tea    莲花绿茶  Scented Tea
# 134  magnolia-oolong                   Magnolia Oolong    玉兰乌龙  Scented Tea
# 135     wuzhen-green                      Wuzhen Green    乌镇绿茶    Green Tea
#
# ...

# %%
df['fp'].value_counts()
# Out:
# fp
# 3    131
# 2      4
# 4      1
# Name: count, dtype: int64
