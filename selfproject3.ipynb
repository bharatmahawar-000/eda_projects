# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as mlp

# %%
df = pd.read_csv('climate_change_dataset.csv')
df
# Out:
#      Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 0    2006         UK                   8.9                          9.3
# 1    2019        USA                  31.0                          4.8
# 2    2014     France                  33.9                          2.8
# 3    2010  Argentina                   5.9                          1.8
# 4    2007    Germany                  26.9                          5.6
# ..    ...        ...                   ...                          ...
# 995  2019      India                  23.6                          8.0
# 996  2000         UK                  21.8                         10.0
# 997  2019  Argentina                  23.8                          8.9
# 998  2016  Australia                  21.0                         14.9
# 999  2011    Germany                  24.1                         17.3
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %%
df.size
# Out:
# 10000

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         1000 non-null   int64
#  1   Country                      1000 non-null   object
#  2   Avg Temperature (°C)         1000 non-null   float64
#  3   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  4   Sea Level Rise (mm)          1000 non-null   float64
#  5   Rainfall (mm)                1000 non-null   int64
#  6   Population                   1000 non-null   int64
#  7   Renewable Energy (%)         1000 non-null   float64
#  8   Extreme Weather Events       1000 non-null   int64
#  9   Forest Area (%)              1000 non-null   float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 78.3+ KB

# %%
df.describe()
# Out:
#               Year  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# count  1000.000000           1000.000000                  1000.000000
# mean   2011.432000             19.883100                    10.425800
# std       7.147199              8.542897                     5.614665
# min    2000.000000              5.000000                     0.500000
# 25%    2005.000000             12.175000                     5.575000
# 50%    2012.000000             20.100000                    10.700000
# 75%    2018.000000             27.225000                    15.400000
# max    2023.000000             34.900000                    20.000000
#
#        Sea Level Rise (mm)  Rainfall (mm)    Population  Renewable Energy (%)  \
# count          1000.000000    1000.000000  1.000000e+03           1000.000000
# mean              3.009600    1738.761000  7.053830e+08             27.300500
# std               1.146081     708.976616  4.093910e+08             12.970808
# ...

# %%
df.isnull().sum()
# Out:
# Year                           0
# Country                        0
# Avg Temperature (°C)           0
# CO2 Emissions (Tons/Capita)    0
# Sea Level Rise (mm)            0
# Rainfall (mm)                  0
# Population                     0
# Renewable Energy (%)           0
# Extreme Weather Events         0
# Forest Area (%)                0
# dtype: int64

# %%
df.head()
# Out:
#    Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 0  2006         UK                   8.9                          9.3
# 1  2019        USA                  31.0                          4.8
# 2  2014     France                  33.9                          2.8
# 3  2010  Argentina                   5.9                          1.8
# 4  2007    Germany                  26.9                          5.6
#
#    Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 0                  3.1           1441   530911230                  20.4
# 1                  4.2           2407   107364344                  49.2
# 2                  2.2           1241   441101758                  33.3
# 3                  3.2           1892  1069669579                  23.7
# 4                  2.4           1743   124079175                  12.5
#
#    Extreme Weather Events  Forest Area (%)
# 0                      14             59.8
# ...

# %%
df.tail()
# Out:
#      Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 995  2019      India                  23.6                          8.0
# 996  2000         UK                  21.8                         10.0
# 997  2019  Argentina                  23.8                          8.9
# 998  2016  Australia                  21.0                         14.9
# 999  2011    Germany                  24.1                         17.3
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 995                  1.2           1365  1358019778                  10.0
# 996                  2.2           1273   876123161                  14.9
# 997                  4.7            891  1120533308                  25.9
# 998                  3.1           1136   380662109                  24.5
# 999                  2.1           2854   398407112                  41.0
#
#      Extreme Weather Events  Forest Area (%)
# ...

# %%
df[df['Population']==df['Population'].max()]
# Out:
#      Year Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 700  2007  Russia                  24.9                         12.4
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 700                  4.3           1450  1397016073                  39.7
#
#      Extreme Weather Events  Forest Area (%)
# 700                      12             66.5

# %%
top_country = df.sort_values(by='Population',ascending=False).drop_duplicates().head(10)
top_country
# Out:
#      Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 700  2007     Russia                  24.9                         12.4
# 37   2019     Canada                  21.8                          1.0
# 341  2016     Brazil                  28.1                         16.9
# 622  2017     Canada                  16.3                          2.3
# 344  2020     Brazil                  14.1                          3.3
# 960  2010     Mexico                  31.0                         16.6
# 456  2000  Australia                  11.4                          2.2
# 595  2022         UK                   7.5                         19.2
# 273  2002     Canada                  18.3                         11.5
# 805  2017      Japan                  29.8                          1.9
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 700                  4.3           1450  1397016073                  39.7
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated('Country').value_counts()
# Out:
# True     985
# False     15
# Name: count, dtype: int64

# %%
df[df['Country']=='India']['Population'].sum()
# Out:
# np.int64(45963624659)

# %%
df.duplicated('Year').value_counts()
# Out:
# True     976
# False     24
# Name: count, dtype: int64

# %%
df[df['Country'] == 'India']
# Out:
#      Year Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 15   2023   India                  31.0                         17.6
# 22   2005   India                   7.7                          6.1
# 25   2000   India                  20.9                         15.9
# 46   2003   India                  18.9                         19.0
# 52   2019   India                  27.7                          5.1
# ..    ...     ...                   ...                          ...
# 955  2005   India                  24.7                         10.6
# 956  2005   India                  34.8                         15.8
# 979  2016   India                  16.4                          6.7
# 981  2005   India                  17.4                          2.0
# 995  2019   India                  23.6                          8.0
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %%
df[df['CO2 Emissions (Tons/Capita)'] == df['CO2 Emissions (Tons/Capita)'].min()]
# Out:
#      Year  Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 110  2009  Germany                   6.3                          0.5
# 314  2002      USA                  17.0                          0.5
# 613  2011       UK                  19.6                          0.5
# 856  2018   Brazil                   9.8                          0.5
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 110                  1.1           1801    64317241                  49.3
# 314                  3.5           1184    84528761                   7.3
# 613                  3.3           1256   167459760                  27.7
# 856                  1.0            656   239135473                  20.6
#
#      Extreme Weather Events  Forest Area (%)
# 110                       3             37.5
# 314                      14             21.4
# 613                       9             59.6
# 856                       5             51.3

# %%
df[df['CO2 Emissions (Tons/Capita)'] == df['CO2 Emissions (Tons/Capita)'].max ()]
# Out:
#      Year Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 237  2015  Brazil                  28.9                         20.0
# 425  2012   China                  12.7                         20.0
# 707  2021      UK                  17.1                         20.0
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 237                  3.5           2017  1213528698                  12.2
# 425                  4.1           2701  1014597705                  46.0
# 707                  5.0           2022   284705392                  41.0
#
#      Extreme Weather Events  Forest Area (%)
# 237                       7             47.8
# 425                      11             57.3
# 707                      14             52.7

# %%
df.groupby('Country')['Avg Temperature (°C)'].mean()
# Out:
# Country
# Argentina       19.298507
# Australia       19.449123
# Brazil          20.835821
# Canada          20.011940
# China           20.282090
# France          19.383333
# Germany         20.288525
# India           19.764286
# Indonesia       18.918667
# Japan           20.453968
# Mexico          20.696364
# Russia          20.718919
# South Africa    20.738356
# UK              18.490769
# USA             19.049315
# Name: Avg Temperature (°C), dtype: float64

# %%
df[df['Population']>50000000].drop_duplicates('Country')
# Out:
#     Year       Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 0   2006            UK                   8.9                          9.3
# 1   2019           USA                  31.0                          4.8
# 2   2014        France                  33.9                          2.8
# 3   2010     Argentina                   5.9                          1.8
# 4   2007       Germany                  26.9                          5.6
# 5   2020         China                  32.3                          1.4
# 7   2018  South Africa                  33.9                          6.0
# 9   2010     Australia                  18.3                          1.9
# 10  2010     Indonesia                  14.4                          4.9
# 12  2020        Brazil                  26.7                         12.2
# 15  2023         India                  31.0                         17.6
# 19  2001        Canada                  21.3                         12.7
# ...

# %%
avg =df['Avg Temperature (°C)'].mean()
df[df['Avg Temperature (°C)']>avg]['Country']
# Out:
# 1            USA
# 2         France
# 4        Germany
# 5          China
# 6      Argentina
#          ...
# 995        India
# 996           UK
# 997    Argentina
# 998    Australia
# 999      Germany
# Name: Country, Length: 508, dtype: object

# %%
df[['Country','Year','Population','CO2 Emissions (Tons/Capita)']]
# Out:
#        Country  Year  Population  CO2 Emissions (Tons/Capita)
# 0           UK  2006   530911230                          9.3
# 1          USA  2019   107364344                          4.8
# 2       France  2014   441101758                          2.8
# 3    Argentina  2010  1069669579                          1.8
# 4      Germany  2007   124079175                          5.6
# ..         ...   ...         ...                          ...
# 995      India  2019  1358019778                          8.0
# 996         UK  2000   876123161                         10.0
# 997  Argentina  2019  1120533308                          8.9
# 998  Australia  2016   380662109                         14.9
# 999    Germany  2011   398407112                         17.3
#
# [1000 rows x 4 columns]

# %%
df[df['Population']>1000000000]
# Out:
#      Year       Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 3    2010     Argentina                   5.9                          1.8
# 5    2020         China                  32.3                          1.4
# 10   2010     Indonesia                  14.4                          4.9
# 11   2023  South Africa                  14.6                         14.7
# 12   2020        Brazil                  26.7                         12.2
# ..    ...           ...                   ...                          ...
# 989  2011            UK                  26.2                          8.6
# 993  2003  South Africa                  30.2                          8.5
# 994  2018     Australia                  34.5                         14.6
# 995  2019         India                  23.6                          8.0
# 997  2019     Argentina                  23.8                          8.9
#
# ...

# %%
df[df['Avg Temperature (°C)']>25]
# Out:
#      Year       Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 1    2019           USA                  31.0                          4.8
# 2    2014        France                  33.9                          2.8
# 4    2007       Germany                  26.9                          5.6
# 5    2020         China                  32.3                          1.4
# 6    2006     Argentina                  30.7                         11.6
# ..    ...           ...                   ...                          ...
# 990  2004        Canada                  34.2                          0.8
# 991  2005     Indonesia                  29.8                          6.3
# 992  2021     Indonesia                  26.0                          9.5
# 993  2003  South Africa                  30.2                          8.5
# 994  2018     Australia                  34.5                         14.6
#
# ...

# %%
CO2_mean = df['CO2 Emissions (Tons/Capita)'].mean()
df[(df['Population']>500000000)&(df['CO2 Emissions (Tons/Capita)']>CO2_mean)]
# Out:
#      Year       Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 6    2006     Argentina                  30.7                         11.6
# 8    2022            UK                  27.8                         16.6
# 11   2023  South Africa                  14.6                         14.7
# 12   2020        Brazil                  26.7                         12.2
# 14   2007       Germany                  11.0                         17.6
# ..    ...           ...                   ...                          ...
# 974  2010        Brazil                   5.0                         15.8
# 982  2018     Indonesia                  29.1                         16.7
# 984  2014           USA                   5.5                         10.7
# 985  2010        Brazil                  17.6                         16.0
# 994  2018     Australia                  34.5                         14.6
#
# ...

# %%
sea_mean = df['Sea Level Rise (mm)'].mean()
df[(df['Sea Level Rise (mm)']>avg)&(df['Avg Temperature (°C)']<10)]
# Out:
# Empty DataFrame
# Columns: [Year, Country, Avg Temperature (°C), CO2 Emissions (Tons/Capita), Sea Level Rise (mm), Rainfall (mm), Population, Renewable Energy (%), Extreme Weather Events, Forest Area (%)]
# Index: []

# %%
df[df['Year']<2020]
# Out:
#      Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 0    2006         UK                   8.9                          9.3
# 1    2019        USA                  31.0                          4.8
# 2    2014     France                  33.9                          2.8
# 3    2010  Argentina                   5.9                          1.8
# 4    2007    Germany                  26.9                          5.6
# ..    ...        ...                   ...                          ...
# 995  2019      India                  23.6                          8.0
# 996  2000         UK                  21.8                         10.0
# 997  2019  Argentina                  23.8                          8.9
# 998  2016  Australia                  21.0                         14.9
# 999  2011    Germany                  24.1                         17.3
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %%
df.groupby('Country')['Population'].max()
# Out:
# Country
# Argentina       1356785799
# Australia       1388230143
# Brazil          1393981934
# Canada          1395185778
# China           1358197397
# France          1379671819
# Germany         1377569278
# India           1366390185
# Indonesia       1358606331
# Japan           1385374585
# Mexico          1388289771
# Russia          1397016073
# South Africa    1383289354
# UK              1387457528
# USA             1380798693
# Name: Population, dtype: int64

# %%
df.groupby('Country')['Avg Temperature (°C)'].min()
# Out:
# Country
# Argentina       5.7
# Australia       5.4
# Brazil          5.0
# Canada          5.5
# China           5.4
# France          5.1
# Germany         5.1
# India           5.3
# Indonesia       5.5
# Japan           5.7
# Mexico          5.1
# Russia          5.3
# South Africa    5.0
# UK              5.0
# USA             5.5
# Name: Avg Temperature (°C), dtype: float64

# %%
df.groupby('Country')['CO2 Emissions (Tons/Capita)'].mean()
# Out:
# Country
# Argentina       10.447761
# Australia        8.900000
# Brazil          10.838806
# Canada          10.113433
# China           10.835821
# France          10.966667
# Germany          9.880328
# India           10.694286
# Indonesia       11.021333
# Japan           10.960317
# Mexico           9.347273
# Russia           8.967568
# South Africa     9.617808
# UK              12.650769
# USA             10.882192
# Name: CO2 Emissions (Tons/Capita), dtype: float64

# %%
df['Country'].nunique()
# Out:
# 15

# %%
df.groupby('Country')['Sea Level Rise (mm)'].mean()
# Out:
# Country
# Argentina       3.168657
# Australia       3.164912
# Brazil          3.174627
# Canada          3.138806
# China           2.932836
# France          3.193939
# Germany         2.870492
# India           2.901429
# Indonesia       2.753333
# Japan           3.076190
# Mexico          2.689091
# Russia          3.287838
# South Africa    2.890411
# UK              2.958462
# USA             2.926027
# Name: Sea Level Rise (mm), dtype: float64

# %%
df.head()
# Out:
#    Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 0  2006         UK                   8.9                          9.3
# 1  2019        USA                  31.0                          4.8
# 2  2014     France                  33.9                          2.8
# 3  2010  Argentina                   5.9                          1.8
# 4  2007    Germany                  26.9                          5.6
#
#    Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 0                  3.1           1441   530911230                  20.4
# 1                  4.2           2407   107364344                  49.2
# 2                  2.2           1241   441101758                  33.3
# 3                  3.2           1892  1069669579                  23.7
# 4                  2.4           1743   124079175                  12.5
#
#    Extreme Weather Events  Forest Area (%)
# 0                      14             59.8
# ...

# %%
df.groupby('Country')['Forest Area (%)'].mean()
# Out:
# Country
# Argentina       38.832836
# Australia       40.852632
# Brazil          39.774627
# Canada          41.932836
# China           44.302985
# France          39.496970
# Germany         42.598361
# India           38.990000
# Indonesia       40.524000
# Japan           38.120635
# Mexico          43.376364
# Russia          38.509459
# South Africa    41.072603
# UK              42.718462
# USA             38.534247
# Name: Forest Area (%), dtype: float64

# %%
df.sort_values(by=['Population'],ascending=True)
# Out:
#      Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 838  2010      China                  30.9                         12.1
# 732  2021      Japan                  16.1                          3.6
# 251  2017     Brazil                   7.7                         18.2
# 575  2003      India                   6.4                          9.4
# 853  2002  Indonesia                   5.5                         11.9
# ..    ...        ...                   ...                          ...
# 344  2020     Brazil                  14.1                          3.3
# 622  2017     Canada                  16.3                          2.3
# 341  2016     Brazil                  28.1                         16.9
# 37   2019     Canada                  21.8                          1.0
# 700  2007     Russia                  24.9                         12.4
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %%
df.sort_values(by='Sea Level Rise (mm)')
# Out:
#      Year       Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 742  2000        Mexico                  25.6                          3.3
# 207  2001            UK                  25.6                         16.8
# 856  2018        Brazil                   9.8                          0.5
# 857  2020        Russia                  12.7                          3.9
# 311  2023     Argentina                  22.4                          4.4
# ..    ...           ...                   ...                          ...
# 448  2000     Indonesia                  20.0                         18.7
# 901  2002         India                   8.5                          0.8
# 904  2013     Argentina                  34.7                          7.4
# 813  2000        Russia                  15.1                         15.8
# 872  2012  South Africa                  18.2                         18.8
#
# ...

# %% [markdown]
# Q3
# Find countries where Renewable Energy (%) is greater than Forest Area (%).

# %%
df[df['Renewable Energy (%)'] > df['Forest Area (%)']]['Country']
# Out:
# 1               USA
# 3         Argentina
# 5             China
# 11     South Africa
# 13              USA
#            ...
# 983       Australia
# 988          Canada
# 990          Canada
# 991       Indonesia
# 999         Germany
# Name: Country, Length: 295, dtype: object

# %% [markdown]
# Q4
#
# Display all countries whose rainfall is between 800 mm and 1200 mm.

# %%
df[(df['Rainfall (mm)']>800) & (df['Rainfall (mm)']<1200)]
# Out:
#      Year       Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 7    2018  South Africa                  33.9                          6.0
# 11   2023  South Africa                  14.6                         14.7
# 21   2011        Mexico                  11.1                         16.8
# 25   2000         India                  20.9                         15.9
# 26   2011     Australia                   5.5                         11.7
# ..    ...           ...                   ...                          ...
# 984  2014           USA                   5.5                         10.7
# 992  2021     Indonesia                  26.0                          9.5
# 994  2018     Australia                  34.5                         14.6
# 997  2019     Argentina                  23.8                          8.9
# 998  2016     Australia                  21.0                         14.9
#
# ...

# %% [markdown]
#  Q7
#
# Find the top 3 countries every year based on population.

# %%
 df.groupby('Year').apply(lambda x : x.sort_values(by='Population',ascending=False).head(3))
# Out:
# C:\Users\BHARAT\AppData\Local\Temp\ipykernel_24536\2207331437.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Year').apply(lambda x : x.sort_values(by='Population',ascending=False).head(3))
#           Year       Country  Avg Temperature (°C)  \
# Year
# 2000 456  2000     Australia                  11.4
#      731  2000           USA                  12.1
#      94   2000            UK                  22.9
# 2001 743  2001       Germany                  34.7
#      73   2001  South Africa                  34.3
# ...        ...           ...                   ...
# 2022 357  2022         Japan                  10.4
#      558  2022           USA                  29.3
# ...

# %% [markdown]
# Q8
#
# Find the bottom 5 countries every year based on forest area.

# %%
df.groupby('Year',group_keys=False).apply(lambda x : x.sort_values(by='Forest Area (%)',ascending=True).head(5))
# Out:
# C:\Users\BHARAT\AppData\Local\Temp\ipykernel_24536\762575639.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Year',group_keys=False).apply(lambda x : x.sort_values(by='Forest Area (%)',ascending=True).head(5))
#      Year       Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 631  2000  South Africa                  34.8                          8.6
# 731  2000           USA                  12.1                          9.3
# 951  2000       Germany                  14.4                          0.7
# 508  2000  South Africa                  24.0                         14.3
# 769  2000         India                  32.3                          6.5
# ...

# %% [markdown]
# Q9
#
# Display the country with the highest CO₂ emission for every year.

# %%
df.groupby('Year').apply(lambda x : x.sort_values(by='CO2 Emissions (Tons/Capita)').head(1))
# Out:
# C:\Users\BHARAT\AppData\Local\Temp\ipykernel_24536\354355173.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Year').apply(lambda x : x.sort_values(by='CO2 Emissions (Tons/Capita)').head(1))
#           Year       Country  Avg Temperature (°C)  \
# Year
# 2000 951  2000       Germany                  14.4
# 2001 330  2001         India                  20.8
# 2002 314  2002           USA                  17.0
# 2003 288  2003           USA                  12.4
# 2004 990  2004        Canada                  34.2
# 2005 863  2005     Indonesia                   7.8
# 2006 113  2006        Brazil                  24.6
# 2007 63   2007         Japan                  15.4
# ...
