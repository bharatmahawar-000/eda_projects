# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as mlp 
import seaborn as sns

# %%
df = pd.read_csv('people-1000.csv')
df
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          1000 non-null   int64
#  1   User Id        1000 non-null   object
#  2   First Name     1000 non-null   object
#  3   Last Name      1000 non-null   object
#  4   Sex            1000 non-null   object
#  5   Email          1000 non-null   object
#  6   Phone          1000 non-null   object
#  7   Date of birth  1000 non-null   object
#  8   Job Title      1000 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#              Index
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.size
# Out:
# 9000

# %%
df.columns
# Out:
# Index(['Index', 'User Id', 'First Name', 'Last Name', 'Sex', 'Email', 'Phone',
#        'Date of birth', 'Job Title'],
#       dtype='object')

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 2            fhoward@example.org       (599)782-0605    2013-11-25
# 3          zjohnston@example.com     +1-939-130-6258    2012-11-17
# 4               elin@example.net  (390)417-1635x3010    1923-04-15
#
#                   Job Title
# 0         Probation officer
# 1                    Dancer
# 2                      Copy
# 3  Counselling psychologist
# 4       Biomedical engineer

# %%
df.tail()
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                        Email                  Phone Date of birth  \
# 995   lyonsdaisy@example.net           021.775.2933    1959-01-05
# 996  dariusbryan@example.com   001-149-710-7799x721    2001-10-06
# 997   georgechan@example.org  +1-750-774-4128x33265    1918-05-13
# 998      wanda04@example.net          (915)292-2254    1971-08-31
# 999  deannablack@example.org     079.752.5424x67259    1947-01-24
#
#                            Job Title
# 995                Personnel officer
# 996          Education administrator
# 997  Commercial/residential surveyor
# 998                 Ambulance person
# ...

# %%
df.sample()
# Out:
#      Index          User Id First Name Last Name   Sex  \
# 897    898  510DAC1BE6C39ef  Gabriella      Pena  Male
#
#                        Email             Phone Date of birth  \
# 897  erikahansen@example.org  684-789-9132x271    1971-12-30
#
#                   Job Title
# 897  Chief Strategy Officer

# %%
df.describe(include='object')
# Out:
#                 User Id First Name Last Name   Sex                Email  \
# count              1000       1000      1000  1000                 1000
# unique             1000        526       628     2                 1000
# top     8717bbf45cCDbEe      Lydia      Duke  Male  pwarner@example.org
# freq                  1          6         6   506                    1
#
#                Phone Date of birth         Job Title
# count           1000          1000              1000
# unique          1000           991               519
# top     857.139.8239    1955-07-31  Paediatric nurse
# freq               1             2                 7

# %%
df.isna().sum()
# Out:
# Index            0
# User Id          0
# First Name       0
# Last Name        0
# Sex              0
# Email            0
# Phone            0
# Date of birth    0
# Job Title        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 2            fhoward@example.org       (599)782-0605    2013-11-25
# 3          zjohnston@example.com     +1-939-130-6258    2012-11-17
# 4               elin@example.net  (390)417-1635x3010    1923-04-15
#
#                   Job Title
# 0         Probation officer
# 1                    Dancer
# 2                      Copy
# 3  Counselling psychologist
# 4       Biomedical engineer

# %%
birth_year = df['Date of birth'].apply(lambda x : int(x.split('-')[0]))
df['Age'] = 2026 - birth_year

# %%
 df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 2            fhoward@example.org       (599)782-0605    2013-11-25
# 3          zjohnston@example.com     +1-939-130-6258    2012-11-17
# 4               elin@example.net  (390)417-1635x3010    1923-04-15
#
#                   Job Title  Birth Year  Age
# 0         Probation officer          12   12
# 1                    Dancer          95   95
# 2                      Copy          13   13
# ...

# %%
df['Sex'].value_counts()
# Out:
# Sex
# Male      506
# Female    494
# Name: count, dtype: int64

# %%
df[(df['Sex']=='Male') & (df['Age'] >= 50)].count()
# Out:
# Index            294
# User Id          294
# First Name       294
# Last Name        294
# Sex              294
# Email            294
# Phone            294
# Date of birth    294
# Job Title        294
# Birth Year       294
# Age              294
# dtype: int64

# %%
df['Job Title'].value_counts(ascending=False).head(10)
# Out:
# Job Title
# Paediatric nurse              7
# Phytotherapist                7
# Nurse, adult                  6
# Production engineer           6
# Nurse, mental health          6
# Social worker                 5
# Metallurgist                  5
# Architectural technologist    5
# Personnel officer             5
# Therapeutic radiographer      5
# Name: count, dtype: int64

# %%
df[(df['Age'] > 13) & (df['Age']<24)] .count() # for youth
# Out:
# Index            83
# User Id          83
# First Name       83
# Last Name        83
# Sex              83
# Email            83
# Phone            83
# Date of birth    83
# Job Title        83
# Birth Year       83
# Age              83
# dtype: int64

# %%
df['Last Name'].value_counts(ascending=False).head(20)
# Out:
# Last Name
# Duke        6
# Nixon       5
# Camacho     5
# Bruce       5
# Esparza     4
# Fritz       4
# Bolton      4
# Jenkins     4
# Wallace     4
# Moore       4
# Knox        4
# Ramos       4
# Obrien      4
# Hess        4
# Sims        4
# Koch        4
# Flowers     4
# Donovan     4
# Cisneros    4
# Olson       4
# Name: count, dtype: int64

# %%
df['Job Title'].value_counts(ascending=True).head(10)
# Out:
# Job Title
# Nurse, learning disability                   1
# Retail manager                               1
# Sound technician, broadcasting/film/video    1
# Public house manager                         1
# Trade mark attorney                          1
# Landscape architect                          1
# Manufacturing systems engineer               1
# Adult nurse                                  1
# Administrator, sports                        1
# Production manager                           1
# Name: count, dtype: int64

# %%
df["First Name"].value_counts(ascending=True).head(200)
# Out:
# First Name
# Lee          1
# Douglas      1
# Howard       1
# Lisa         1
# Sherri       1
#             ..
# Jane         1
# Elizabeth    1
# Neil         1
# Kelli        1
# Greg         1
# Name: count, Length: 200, dtype: int64

# %%
df.loc[df['Age'].idxmin()]
# Out:
# Index                                    150
# User Id                      5627680A2Ca214B
# First Name                             Malik
# Last Name                            Summers
# Sex                                     Male
# Email                     lynn40@example.org
# Phone                  +1-584-890-5151x25199
# Date of birth                     2022-03-28
# Job Title        Health promotion specialist
# Birth Year                                 4
# Age                                        4
# Name: 149, dtype: object

# %%
df.loc[df['Age'].idxmax()]
# Out:
# Index                                      63
# User Id                       11Ae1fbab4076b2
# First Name                            Yesenia
# Last Name                             Harding
# Sex                                      Male
# Email            robertablackburn@example.com
# Phone                      (752)468-1821x6065
# Date of birth                      1906-10-28
# Job Title                Nurse, mental health
# Birth Year                                120
# Age                                       120
# Name: 62, dtype: object

# %%
df['Age'].mean()
# Out:
# np.float64(61.314)

# %%
df['Age'].median()
# Out:
# 61.0

# %%
pd.crosstab(df['Job Title'],df['Sex'])
# Out:
# Sex                                   Female  Male
# Job Title
# Academic librarian                         2     3
# Accommodation manager                      1     1
# Accountant, chartered                      0     1
# Accountant, chartered certified            2     1
# Accountant, chartered public finance       1     2
# ...                                      ...   ...
# Water quality scientist                    0     2
# Web designer                               3     0
# Wellsite geologist                         1     0
# Writer                                     1     2
# Youth worker                               2     0
#
# [519 rows x 2 columns]

# %%
sns.barplot(y= df['Job Title'].head(10) , x= df['Sex'],palette='muted')
# Out:
# C:\Users\BHARAT\AppData\Local\Temp\ipykernel_28164\2232194134.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y= df['Job Title'].head(10) , x= df['Sex'],palette='muted')
# <Axes: xlabel='Sex', ylabel='Job Title'>

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 2            fhoward@example.org       (599)782-0605    2013-11-25
# 3          zjohnston@example.com     +1-939-130-6258    2012-11-17
# 4               elin@example.net  (390)417-1635x3010    1923-04-15
#
#                   Job Title  Birth Year  Age
# 0         Probation officer          12   12
# 1                    Dancer          95   95
# 2                      Copy          13   13
# ...
